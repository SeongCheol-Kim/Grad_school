# %%
import os
import random
import numpy as np
import tensorflow as tf
from collections import deque

from nes_py.wrappers import JoypadSpace
import gym
import gym_tetris
from gym_tetris.actions import MOVEMENT

from skimage.color import rgb2gray
from skimage.transform import resize

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %%
# 상태가 입력, 큐함수가 출력인 인공신경망 생성
class DQN(tf.keras.Model):
    def __init__(self, action_size, state_size):
        super(DQN, self).__init__()
        self.conv1 = Conv2D(32, (8, 8), strides=(4, 4), activation='relu',
                            input_shape=state_size)
        self.conv2 = Conv2D(64, (4, 4), strides=(2, 2), activation='relu')
        self.conv3 = Conv2D(64, (3, 3), strides=(1, 1), activation='relu')
        self.flatten = Flatten()
        self.fc = Dense(512, activation='relu')
        self.fc_out = Dense(action_size)

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        x = self.fc(x)
        q = self.fc_out(x)
        return q

# %%
class Agent:
    def __init__(self, action_size, state_size=(84, 84, 4)):
        self.render = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 1e-4
        self.epsilon = 1.0
        self.epsilon_start = 1.0
        self.epsilon_end  = 0.1
        self.exploration_steps = 1000000
        self.epsilon_decay_step = self.epsilon_start - self.epsilon_end
        self.epsilon_decay_step /= self.exploration_steps
        self.batch_size = 32
        self.train_start = 50000
        self.update_target_rate = 10000

        # 리플레이 메모리, 최대 크기 100,000
        self.memory = deque(maxlen=100000)
        
#         # 게임 시작 후 랜덤하게 움직이지 않는 것에 대한 옵션
#         self.no_op_steps = 30

        # 모델과 타깃 모델 생성
        self.model = DQN(action_size, state_size)
        self.target_model = DQN(action_size, state_size)
        self.optimizer = Adam(self.learning_rate, clipnorm=10.)
        
        # 타깃 모델 초기화
        self.update_target_model()

        self.avg_q_max, self.avg_loss = 0, 0

        self.writer = tf.summary.create_file_writer('summary/Tetris_DQN')
        self.model_path = os.path.join(os.getcwd(), 'save_model', 'model')

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def get_action(self, history):
        
        # action selection with e-greedy policy
        history = np.float32(history / 255.0)
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model(history)
            return np.argmax(q_value[0])

    def append_sample(self, history, action, reward, next_history):
        # 샘플 <s, a, r, s'>을 메모리에 저장
        self.memory.append((history, action, reward, next_history, done))

    # 텐서보드에 학습 정보를 기록
    def draw_tensorboard(self, score, step, episode):
        with self.writer.as_default():
            tf.summary.scalar('Total Reward/Episode', score, step=episode)
            tf.summary.scalar('Average Max Q/Episode',
                              self.avg_q_max / float(step), step=episode)
            tf.summary.scalar('Duration/Episode', step, step=episode)
            tf.summary.scalar('Average Loss/Episode',
                              self.avg_loss / float(step), step=episode)

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_end:
            self.epsilon -= self.epsilon_decay_step

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        batch = random.sample(self.memory, self.batch_size)
#         temp_batch = np.array(batch)
#         print(temp_batch.shape)
#         print("\n")

        history = np.array([sample[0][0] / 255. for sample in batch],
                           dtype=np.float32)
        actions = np.array([sample[1] for sample in batch])
        rewards = np.array([sample[2] for sample in batch])
        next_history = np.array([sample[3][0] / 255. for sample in batch],
                                dtype=np.float32)
#         dones = np.array([sample[4] for sample in batch])
#         print(dones)
#         print("==============================================================================")

        # 학습 파라메터
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            # 현재 상태에 대한 모델의 큐함수
            predicts = self.model(history)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)

            # 다음 상태에 대한 타깃 모델의 큐함수
            target_predicts = self.target_model(next_history)

            # 벨만 최적 방정식을 구성하기 위한 타깃과 큐함수의 최대 값 계산
            max_q = np.amax(target_predicts, axis=1)
            targets = rewards + self.discount_factor * max_q

            # 후버로스 계산
            error = tf.abs(targets - predicts)
            quadratic_part = tf.clip_by_value(error, 0.0, 1.0)
            linear_part = error - quadratic_part
            loss = tf.reduce_mean(0.5 * tf.square(quadratic_part) + linear_part)

            self.avg_loss += loss.numpy()

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))


def pre_processing(observe):
    # RGB to GRAY
    processed_observe = np.uint8(resize(rgb2gray(observe), (84, 84), mode='constant') * 255)
    
    return processed_observe

# %%
if __name__ == "__main__":
    # 환경과 DQN 에이전트 생성
    env = gym_tetris.make('TetrisA-v0')
    env = JoypadSpace(env, MOVEMENT)
    agent = Agent(action_size=12)

    global_step = 0
    score_avg = 0
    score_max = 0

    num_episode = 50000
    
    for e in range(num_episode):
        done = False

        step, score = 0, 0, 
        # env 초기화
        observe = env.reset()

#         # 랜덤으로 뽑힌 값 만큼의 프레임동안 움직이지 않음
#         for _ in range(random.randint(1, agent.no_op_steps)):
#             observe, _, _, _ = env.step(1)

        # 프레임을 전처리 한 후 4개의 상태를 쌓아서 입력값으로 사용.
        state = pre_processing(observe)
        history = np.stack((state, state, state, state), axis=2)
        history = np.reshape([history], (1, 84, 84, 4))

        while not done:
            if agent.render:
                env.render()
            global_step += 1
            step += 1

            # 바로 전 history를 입력으로 받아 행동을 선택
            action = agent.get_action(history)

            # 선택한 행동으로 환경에서 한 타임스텝 진행
            observe, reward, done, info = env.step(action)
            # 각 타임스텝마다 상태 전처리
            next_state = pre_processing(observe)
            next_state = np.reshape([next_state], (1, 84, 84, 1))
            next_history = np.append(next_state, history[:, :, :, :3], axis=3)

            agent.avg_q_max += np.amax(agent.model(np.float32(history / 255.0))[0])

            score += reward
            reward = np.clip(reward, -1., 1.)
            # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장 후 학습
            agent.append_sample(history, action, reward, next_history)

            # 리플레이 메모리 크기가 정해놓은 수치에 도달한 시점부터 모델 학습 시작
            if len(agent.memory) >= agent.train_start:
                agent.train_model()
                # 일정 시간마다 타겟모델을 모델의 가중치로 업데이트
                if global_step % agent.update_target_rate == 0:
                    agent.update_target_model()

            if done:
                # 각 에피소드 당 학습 정보를 기록
                if global_step > agent.train_start:
                    agent.draw_tensorboard(int(score), step, e)

                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                score_max = score if score > score_max else score_max

                log = "episode: {:5d} | ".format(e)
                log += "score: {:4.1f} | ".format(score)
                log += "score max : {:4.1f} | ".format(score_max)
                log += "score avg: {:4.1f} | ".format(score_avg)
                log += "memory length: {:5d} | ".format(len(agent.memory))
                log += "epsilon: {:.3f} | ".format(agent.epsilon)
                log += "q avg : {:3.2f} | ".format(agent.avg_q_max / float(step))
                log += "avg loss : {:3.2f}".format(agent.avg_loss / float(step))
                print(log)

                agent.avg_q_max, agent.avg_loss = 0, 0

        # 1000 에피소드마다 모델 저장
        if e % 1000 == 0:
            agent.model.save_weights("./save_model/model", save_format="tf")
# Out:
# episode:     0 | score:  1.0 | score max :  1.0 | score avg:  1.0 | memory length:  7824 | epsilon: 1.000 | q avg : 0.07 | avg loss : 0.00
# episode:     1 | score:  2.0 | score max :  2.0 | score avg:  1.1 | memory length: 16007 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     2 | score:  0.0 | score max :  2.0 | score avg:  1.0 | memory length: 26362 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     3 | score:  0.0 | score max :  2.0 | score avg:  0.9 | memory length: 34708 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     4 | score:  1.0 | score max :  2.0 | score avg:  0.9 | memory length: 40938 | epsilon: 1.000 | q avg : 0.05 | avg loss : 0.00
# episode:     5 | score:  0.0 | score max :  2.0 | score avg:  0.8 | memory length: 52043 | epsilon: 0.998 | q avg : 0.06 | avg loss : 0.00
# episode:     6 | score:  0.0 | score max :  2.0 | score avg:  0.7 | memory length: 59239 | epsilon: 0.992 | q avg : 0.06 | avg loss : 0.00
# episode:     7 | score:  0.0 | score max :  2.0 | score avg:  0.7 | memory length: 70374 | epsilon: 0.982 | q avg : 0.05 | avg loss : 0.00
# episode:     8 | score:  0.0 | score max :  2.0 | score avg:  0.6 | memory length: 79191 | epsilon: 0.974 | q avg : 0.06 | avg loss : 0.00
# episode:     9 | score:  2.0 | score max :  2.0 | score avg:  0.7 | memory length: 86104 | epsilon: 0.968 | q avg : 0.06 | avg loss : 0.00
# episode:    10 | score:  2.0 | score max :  2.0 | score avg:  0.9 | memory length: 93061 | epsilon: 0.961 | q avg : 0.06 | avg loss : 0.00
# episode:    11 | score:  0.0 | score max :  2.0 | score avg:  0.8 | memory length: 100000 | epsilon: 0.953 | q avg : 0.06 | avg loss : 0.00
# episode:    12 | score:  0.0 | score max :  2.0 | score avg:  0.7 | memory length: 100000 | epsilon: 0.946 | q avg : 0.06 | avg loss : 0.00
# episode:    13 | score:  0.0 | score max :  2.0 | score avg:  0.6 | memory length: 100000 | epsilon: 0.939 | q avg : 0.06 | avg loss : 0.00
# episode:    14 | score:  0.0 | score max :  2.0 | score avg:  0.6 | memory length: 100000 | epsilon: 0.931 | q avg : 0.06 | avg loss : 0.00
# episode:    15 | score:  0.0 | score max :  2.0 | score avg:  0.5 | memory length: 100000 | epsilon: 0.924 | q avg : 0.06 | avg loss : 0.00
# episode:    16 | score:  0.0 | score max :  2.0 | score avg:  0.5 | memory length: 100000 | epsilon: 0.918 | q avg : 0.06 | avg loss : 0.00
# episode:    17 | score:  0.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.910 | q avg : 0.06 | avg loss : 0.00
# episode:    18 | score:  0.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.904 | q avg : 0.06 | avg loss : 0.00
# episode:    19 | score:  1.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.895 | q avg : 0.07 | avg loss : 0.00
# episode:    20 | score:  0.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.888 | q avg : 0.07 | avg loss : 0.00
# episode:    21 | score:  0.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.880 | q avg : 0.07 | avg loss : 0.00
# episode:    22 | score:  1.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.876 | q avg : 0.07 | avg loss : 0.00
# episode:    23 | score:  0.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.869 | q avg : 0.07 | avg loss : 0.00
# episode:    24 | score:  0.0 | score max :  2.0 | score avg:  0.3 | memory length: 100000 | epsilon: 0.863 | q avg : 0.07 | avg loss : 0.00
# episode:    25 | score:  1.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.855 | q avg : 0.07 | avg loss : 0.00
# episode:    26 | score:  0.0 | score max :  2.0 | score avg:  0.4 | memory length: 100000 | epsilon: 0.849 | q avg : 0.07 | avg loss : 0.00
# episode:    27 | score:  0.0 | score max :  2.0 | score avg:  0.3 | memory length: 100000 | epsilon: 0.842 | q avg : 0.07 | avg loss : 0.00
# episode:    28 | score:  0.0 | score max :  2.0 | score avg:  0.3 | memory length: 100000 | epsilon: 0.834 | q avg : 0.07 | avg loss : 0.00
# episode:    29 | score:  3.0 | score max :  3.0 | score avg:  0.6 | memory length: 100000 | epsilon: 0.828 | q avg : 0.07 | avg loss : 0.00
# episode:    30 | score:  5.0 | score max :  5.0 | score avg:  1.0 | memory length: 100000 | epsilon: 0.824 | q avg : 0.07 | avg loss : 0.00
# episode:    31 | score:  1.0 | score max :  5.0 | score avg:  1.0 | memory length: 100000 | epsilon: 0.819 | q avg : 0.07 | avg loss : 0.00
# episode:    32 | score:  0.0 | score max :  5.0 | score avg:  0.9 | memory length: 100000 | epsilon: 0.812 | q avg : 0.07 | avg loss : 0.00
# episode:    33 | score:  3.0 | score max :  5.0 | score avg:  1.1 | memory length: 100000 | epsilon: 0.807 | q avg : 0.07 | avg loss : 0.00
# episode:    34 | score:  2.0 | score max :  5.0 | score avg:  1.2 | memory length: 100000 | epsilon: 0.800 | q avg : 0.07 | avg loss : 0.00
# episode:    35 | score:  0.0 | score max :  5.0 | score avg:  1.1 | memory length: 100000 | epsilon: 0.794 | q avg : 0.07 | avg loss : 0.00
# episode:    36 | score:  4.0 | score max :  5.0 | score avg:  1.4 | memory length: 100000 | epsilon: 0.788 | q avg : 0.07 | avg loss : 0.00
# episode:    37 | score:  4.0 | score max :  5.0 | score avg:  1.6 | memory length: 100000 | epsilon: 0.783 | q avg : 0.08 | avg loss : 0.00
# episode:    38 | score:  1.0 | score max :  5.0 | score avg:  1.6 | memory length: 100000 | epsilon: 0.778 | q avg : 0.08 | avg loss : 0.00
# episode:    39 | score:  1.0 | score max :  5.0 | score avg:  1.5 | memory length: 100000 | epsilon: 0.772 | q avg : 0.08 | avg loss : 0.00
# episode:    40 | score:  0.0 | score max :  5.0 | score avg:  1.4 | memory length: 100000 | epsilon: 0.765 | q avg : 0.08 | avg loss : 0.00
# episode:    41 | score:  3.0 | score max :  5.0 | score avg:  1.5 | memory length: 100000 | epsilon: 0.758 | q avg : 0.08 | avg loss : 0.00
# episode:    42 | score: 44.0 | score max : 44.0 | score avg:  5.8 | memory length: 100000 | epsilon: 0.747 | q avg : 0.08 | avg loss : 0.00
# episode:    43 | score:  0.0 | score max : 44.0 | score avg:  5.2 | memory length: 100000 | epsilon: 0.743 | q avg : 0.08 | avg loss : 0.00
# episode:    44 | score:  0.0 | score max : 44.0 | score avg:  4.7 | memory length: 100000 | epsilon: 0.735 | q avg : 0.08 | avg loss : 0.00
# episode:    45 | score:  3.0 | score max : 44.0 | score avg:  4.5 | memory length: 100000 | epsilon: 0.730 | q avg : 0.08 | avg loss : 0.00
# episode:    46 | score:  2.0 | score max : 44.0 | score avg:  4.3 | memory length: 100000 | epsilon: 0.726 | q avg : 0.08 | avg loss : 0.00
# episode:    47 | score:  4.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.721 | q avg : 0.08 | avg loss : 0.00
# episode:    48 | score:  2.0 | score max : 44.0 | score avg:  4.0 | memory length: 100000 | epsilon: 0.716 | q avg : 0.09 | avg loss : 0.00
# episode:    49 | score:  4.0 | score max : 44.0 | score avg:  4.0 | memory length: 100000 | epsilon: 0.710 | q avg : 0.09 | avg loss : 0.00
# episode:    50 | score:  6.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.704 | q avg : 0.09 | avg loss : 0.00
# episode:    51 | score:  4.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.699 | q avg : 0.09 | avg loss : 0.00
# episode:    52 | score:  5.0 | score max : 44.0 | score avg:  4.3 | memory length: 100000 | epsilon: 0.694 | q avg : 0.09 | avg loss : 0.00
# episode:    53 | score:  2.0 | score max : 44.0 | score avg:  4.0 | memory length: 100000 | epsilon: 0.688 | q avg : 0.09 | avg loss : 0.00
# episode:    54 | score:  2.0 | score max : 44.0 | score avg:  3.8 | memory length: 100000 | epsilon: 0.683 | q avg : 0.09 | avg loss : 0.00
# episode:    55 | score: 10.0 | score max : 44.0 | score avg:  4.5 | memory length: 100000 | epsilon: 0.677 | q avg : 0.09 | avg loss : 0.00
# episode:    56 | score:  2.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.671 | q avg : 0.09 | avg loss : 0.00
# episode:    57 | score:  6.0 | score max : 44.0 | score avg:  4.4 | memory length: 100000 | epsilon: 0.665 | q avg : 0.09 | avg loss : 0.00
# episode:    58 | score:  3.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.661 | q avg : 0.10 | avg loss : 0.00
# episode:    59 | score:  4.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.654 | q avg : 0.10 | avg loss : 0.00
# episode:    60 | score:  3.0 | score max : 44.0 | score avg:  4.1 | memory length: 100000 | epsilon: 0.648 | q avg : 0.10 | avg loss : 0.00
# episode:    61 | score:  4.0 | score max : 44.0 | score avg:  4.1 | memory length: 100000 | epsilon: 0.644 | q avg : 0.10 | avg loss : 0.00
# episode:    62 | score:  4.0 | score max : 44.0 | score avg:  4.1 | memory length: 100000 | epsilon: 0.640 | q avg : 0.10 | avg loss : 0.00
# episode:    63 | score:  3.0 | score max : 44.0 | score avg:  4.0 | memory length: 100000 | epsilon: 0.636 | q avg : 0.10 | avg loss : 0.00
# episode:    64 | score:  4.0 | score max : 44.0 | score avg:  4.0 | memory length: 100000 | epsilon: 0.632 | q avg : 0.10 | avg loss : 0.00
# episode:    65 | score:  3.0 | score max : 44.0 | score avg:  3.9 | memory length: 100000 | epsilon: 0.627 | q avg : 0.10 | avg loss : 0.00
# episode:    66 | score:  6.0 | score max : 44.0 | score avg:  4.1 | memory length: 100000 | epsilon: 0.623 | q avg : 0.10 | avg loss : 0.00
# episode:    67 | score:  0.0 | score max : 44.0 | score avg:  3.7 | memory length: 100000 | epsilon: 0.620 | q avg : 0.10 | avg loss : 0.00
# episode:    68 | score:  8.0 | score max : 44.0 | score avg:  4.1 | memory length: 100000 | epsilon: 0.615 | q avg : 0.10 | avg loss : 0.00
# episode:    69 | score:  0.0 | score max : 44.0 | score avg:  3.7 | memory length: 100000 | epsilon: 0.609 | q avg : 0.10 | avg loss : 0.00
# episode:    70 | score:  8.0 | score max : 44.0 | score avg:  4.1 | memory length: 100000 | epsilon: 0.604 | q avg : 0.10 | avg loss : 0.00
# episode:    71 | score:  7.0 | score max : 44.0 | score avg:  4.4 | memory length: 100000 | epsilon: 0.598 | q avg : 0.10 | avg loss : 0.00
# episode:    72 | score:  4.0 | score max : 44.0 | score avg:  4.4 | memory length: 100000 | epsilon: 0.595 | q avg : 0.10 | avg loss : 0.00
# episode:    73 | score:  3.0 | score max : 44.0 | score avg:  4.2 | memory length: 100000 | epsilon: 0.590 | q avg : 0.11 | avg loss : 0.00
# episode:    74 | score: 10.0 | score max : 44.0 | score avg:  4.8 | memory length: 100000 | epsilon: 0.588 | q avg : 0.11 | avg loss : 0.00
# episode:    75 | score: 47.0 | score max : 47.0 | score avg:  9.0 | memory length: 100000 | epsilon: 0.582 | q avg : 0.10 | avg loss : 0.00
# episode:    76 | score:  6.0 | score max : 47.0 | score avg:  8.7 | memory length: 100000 | epsilon: 0.579 | q avg : 0.11 | avg loss : 0.00
# episode:    77 | score:  6.0 | score max : 47.0 | score avg:  8.5 | memory length: 100000 | epsilon: 0.574 | q avg : 0.11 | avg loss : 0.00
# episode:    78 | score:  5.0 | score max : 47.0 | score avg:  8.1 | memory length: 100000 | epsilon: 0.572 | q avg : 0.11 | avg loss : 0.00
# episode:    79 | score:  9.0 | score max : 47.0 | score avg:  8.2 | memory length: 100000 | epsilon: 0.568 | q avg : 0.11 | avg loss : 0.00
# episode:    80 | score: 13.0 | score max : 47.0 | score avg:  8.7 | memory length: 100000 | epsilon: 0.563 | q avg : 0.11 | avg loss : 0.00
# episode:    81 | score:  9.0 | score max : 47.0 | score avg:  8.7 | memory length: 100000 | epsilon: 0.559 | q avg : 0.11 | avg loss : 0.00
# episode:    82 | score:  9.0 | score max : 47.0 | score avg:  8.7 | memory length: 100000 | epsilon: 0.556 | q avg : 0.11 | avg loss : 0.00
# episode:    83 | score:  7.0 | score max : 47.0 | score avg:  8.6 | memory length: 100000 | epsilon: 0.553 | q avg : 0.11 | avg loss : 0.00
# episode:    84 | score: 13.0 | score max : 47.0 | score avg:  9.0 | memory length: 100000 | epsilon: 0.550 | q avg : 0.11 | avg loss : 0.00
# episode:    85 | score: 10.0 | score max : 47.0 | score avg:  9.1 | memory length: 100000 | epsilon: 0.545 | q avg : 0.12 | avg loss : 0.00
# episode:    86 | score:  1.0 | score max : 47.0 | score avg:  8.3 | memory length: 100000 | epsilon: 0.542 | q avg : 0.12 | avg loss : 0.00
# episode:    87 | score: 46.0 | score max : 47.0 | score avg: 12.1 | memory length: 100000 | epsilon: 0.538 | q avg : 0.12 | avg loss : 0.00
# episode:    88 | score: 13.0 | score max : 47.0 | score avg: 12.2 | memory length: 100000 | epsilon: 0.533 | q avg : 0.12 | avg loss : 0.00
# episode:    89 | score:  9.0 | score max : 47.0 | score avg: 11.8 | memory length: 100000 | epsilon: 0.531 | q avg : 0.12 | avg loss : 0.00
# episode:    90 | score: 53.0 | score max : 53.0 | score avg: 16.0 | memory length: 100000 | epsilon: 0.527 | q avg : 0.12 | avg loss : 0.00
# episode:    91 | score:  5.0 | score max : 53.0 | score avg: 14.9 | memory length: 100000 | epsilon: 0.523 | q avg : 0.12 | avg loss : 0.00
# episode:    92 | score: 12.0 | score max : 53.0 | score avg: 14.6 | memory length: 100000 | epsilon: 0.519 | q avg : 0.12 | avg loss : 0.00
# episode:    93 | score: 25.0 | score max : 53.0 | score avg: 15.6 | memory length: 100000 | epsilon: 0.516 | q avg : 0.12 | avg loss : 0.00
# episode:    94 | score: 12.0 | score max : 53.0 | score avg: 15.3 | memory length: 100000 | epsilon: 0.514 | q avg : 0.12 | avg loss : 0.00
# episode:    95 | score:  4.0 | score max : 53.0 | score avg: 14.1 | memory length: 100000 | epsilon: 0.512 | q avg : 0.13 | avg loss : 0.00
# episode:    96 | score: 46.0 | score max : 53.0 | score avg: 17.3 | memory length: 100000 | epsilon: 0.508 | q avg : 0.13 | avg loss : 0.00
# episode:    97 | score:  8.0 | score max : 53.0 | score avg: 16.4 | memory length: 100000 | epsilon: 0.505 | q avg : 0.13 | avg loss : 0.00
# episode:    98 | score: 10.0 | score max : 53.0 | score avg: 15.7 | memory length: 100000 | epsilon: 0.503 | q avg : 0.14 | avg loss : 0.00
# episode:    99 | score:  5.0 | score max : 53.0 | score avg: 14.7 | memory length: 100000 | epsilon: 0.501 | q avg : 0.14 | avg loss : 0.00
# episode:   100 | score: 15.0 | score max : 53.0 | score avg: 14.7 | memory length: 100000 | epsilon: 0.497 | q avg : 0.14 | avg loss : 0.00
# episode:   101 | score:  9.0 | score max : 53.0 | score avg: 14.1 | memory length: 100000 | epsilon: 0.492 | q avg : 0.14 | avg loss : 0.00
# episode:   102 | score: 21.0 | score max : 53.0 | score avg: 14.8 | memory length: 100000 | epsilon: 0.489 | q avg : 0.14 | avg loss : 0.00
# episode:   103 | score:  9.0 | score max : 53.0 | score avg: 14.2 | memory length: 100000 | epsilon: 0.487 | q avg : 0.14 | avg loss : 0.00
# episode:   104 | score: 18.0 | score max : 53.0 | score avg: 14.6 | memory length: 100000 | epsilon: 0.484 | q avg : 0.15 | avg loss : 0.00
# episode:   105 | score: 11.0 | score max : 53.0 | score avg: 14.3 | memory length: 100000 | epsilon: 0.481 | q avg : 0.15 | avg loss : 0.00
# episode:   106 | score:  6.0 | score max : 53.0 | score avg: 13.4 | memory length: 100000 | epsilon: 0.478 | q avg : 0.14 | avg loss : 0.00
# episode:   107 | score:  8.0 | score max : 53.0 | score avg: 12.9 | memory length: 100000 | epsilon: 0.477 | q avg : 0.14 | avg loss : 0.00
# episode:   108 | score: 12.0 | score max : 53.0 | score avg: 12.8 | memory length: 100000 | epsilon: 0.473 | q avg : 0.15 | avg loss : 0.00
# episode:   109 | score: 53.0 | score max : 53.0 | score avg: 16.8 | memory length: 100000 | epsilon: 0.470 | q avg : 0.15 | avg loss : 0.00
# episode:   110 | score:  7.0 | score max : 53.0 | score avg: 15.8 | memory length: 100000 | epsilon: 0.465 | q avg : 0.15 | avg loss : 0.00
# episode:   111 | score: 14.0 | score max : 53.0 | score avg: 15.7 | memory length: 100000 | epsilon: 0.462 | q avg : 0.15 | avg loss : 0.00
# episode:   112 | score:  8.0 | score max : 53.0 | score avg: 14.9 | memory length: 100000 | epsilon: 0.460 | q avg : 0.16 | avg loss : 0.00
# episode:   113 | score: 18.0 | score max : 53.0 | score avg: 15.2 | memory length: 100000 | epsilon: 0.458 | q avg : 0.16 | avg loss : 0.00
# episode:   114 | score: 20.0 | score max : 53.0 | score avg: 15.7 | memory length: 100000 | epsilon: 0.455 | q avg : 0.16 | avg loss : 0.00
# episode:   115 | score: 11.0 | score max : 53.0 | score avg: 15.2 | memory length: 100000 | epsilon: 0.453 | q avg : 0.16 | avg loss : 0.00
# episode:   116 | score: 15.0 | score max : 53.0 | score avg: 15.2 | memory length: 100000 | epsilon: 0.450 | q avg : 0.16 | avg loss : 0.00
# episode:   117 | score: 16.0 | score max : 53.0 | score avg: 15.3 | memory length: 100000 | epsilon: 0.447 | q avg : 0.17 | avg loss : 0.00
# episode:   118 | score: 10.0 | score max : 53.0 | score avg: 14.7 | memory length: 100000 | epsilon: 0.445 | q avg : 0.17 | avg loss : 0.00
# episode:   119 | score: 18.0 | score max : 53.0 | score avg: 15.1 | memory length: 100000 | epsilon: 0.442 | q avg : 0.16 | avg loss : 0.00
# episode:   120 | score:  6.0 | score max : 53.0 | score avg: 14.2 | memory length: 100000 | epsilon: 0.439 | q avg : 0.17 | avg loss : 0.00
# episode:   121 | score: 11.0 | score max : 53.0 | score avg: 13.8 | memory length: 100000 | epsilon: 0.437 | q avg : 0.17 | avg loss : 0.00
# episode:   122 | score:  9.0 | score max : 53.0 | score avg: 13.4 | memory length: 100000 | epsilon: 0.436 | q avg : 0.17 | avg loss : 0.00
# episode:   123 | score: 16.0 | score max : 53.0 | score avg: 13.6 | memory length: 100000 | epsilon: 0.434 | q avg : 0.17 | avg loss : 0.00
# episode:   124 | score: 18.0 | score max : 53.0 | score avg: 14.1 | memory length: 100000 | epsilon: 0.431 | q avg : 0.18 | avg loss : 0.00
# episode:   125 | score:  7.0 | score max : 53.0 | score avg: 13.4 | memory length: 100000 | epsilon: 0.428 | q avg : 0.18 | avg loss : 0.00
# episode:   126 | score: 11.0 | score max : 53.0 | score avg: 13.1 | memory length: 100000 | epsilon: 0.424 | q avg : 0.18 | avg loss : 0.00
# episode:   127 | score: 13.0 | score max : 53.0 | score avg: 13.1 | memory length: 100000 | epsilon: 0.422 | q avg : 0.18 | avg loss : 0.00
# episode:   128 | score: 14.0 | score max : 53.0 | score avg: 13.2 | memory length: 100000 | epsilon: 0.420 | q avg : 0.18 | avg loss : 0.00
# episode:   129 | score: 12.0 | score max : 53.0 | score avg: 13.1 | memory length: 100000 | epsilon: 0.418 | q avg : 0.18 | avg loss : 0.00
# episode:   130 | score:  5.0 | score max : 53.0 | score avg: 12.3 | memory length: 100000 | epsilon: 0.416 | q avg : 0.18 | avg loss : 0.00
# episode:   131 | score: 15.0 | score max : 53.0 | score avg: 12.5 | memory length: 100000 | epsilon: 0.413 | q avg : 0.19 | avg loss : 0.00
# episode:   132 | score: 16.0 | score max : 53.0 | score avg: 12.9 | memory length: 100000 | epsilon: 0.411 | q avg : 0.19 | avg loss : 0.00
# episode:   133 | score: 14.0 | score max : 53.0 | score avg: 13.0 | memory length: 100000 | epsilon: 0.408 | q avg : 0.19 | avg loss : 0.00
# episode:   134 | score: 17.0 | score max : 53.0 | score avg: 13.4 | memory length: 100000 | epsilon: 0.407 | q avg : 0.19 | avg loss : 0.00
# episode:   135 | score: 12.0 | score max : 53.0 | score avg: 13.3 | memory length: 100000 | epsilon: 0.406 | q avg : 0.19 | avg loss : 0.00
# episode:   136 | score: 27.0 | score max : 53.0 | score avg: 14.6 | memory length: 100000 | epsilon: 0.403 | q avg : 0.19 | avg loss : 0.00
# episode:   137 | score:  8.0 | score max : 53.0 | score avg: 14.0 | memory length: 100000 | epsilon: 0.401 | q avg : 0.19 | avg loss : 0.00
# episode:   138 | score: 10.0 | score max : 53.0 | score avg: 13.6 | memory length: 100000 | epsilon: 0.400 | q avg : 0.19 | avg loss : 0.00
# episode:   139 | score: 22.0 | score max : 53.0 | score avg: 14.4 | memory length: 100000 | epsilon: 0.398 | q avg : 0.19 | avg loss : 0.00
# episode:   140 | score: 29.0 | score max : 53.0 | score avg: 15.9 | memory length: 100000 | epsilon: 0.396 | q avg : 0.20 | avg loss : 0.00
# episode:   141 | score: 14.0 | score max : 53.0 | score avg: 15.7 | memory length: 100000 | epsilon: 0.394 | q avg : 0.20 | avg loss : 0.00
# episode:   142 | score: 11.0 | score max : 53.0 | score avg: 15.2 | memory length: 100000 | epsilon: 0.392 | q avg : 0.20 | avg loss : 0.00
# episode:   143 | score: 10.0 | score max : 53.0 | score avg: 14.7 | memory length: 100000 | epsilon: 0.391 | q avg : 0.20 | avg loss : 0.00
# episode:   144 | score: 15.0 | score max : 53.0 | score avg: 14.7 | memory length: 100000 | epsilon: 0.390 | q avg : 0.21 | avg loss : 0.00
# episode:   145 | score: 17.0 | score max : 53.0 | score avg: 15.0 | memory length: 100000 | epsilon: 0.389 | q avg : 0.21 | avg loss : 0.00
# episode:   146 | score: 15.0 | score max : 53.0 | score avg: 15.0 | memory length: 100000 | epsilon: 0.387 | q avg : 0.21 | avg loss : 0.00
# episode:   147 | score: 14.0 | score max : 53.0 | score avg: 14.9 | memory length: 100000 | epsilon: 0.386 | q avg : 0.21 | avg loss : 0.00
# episode:   148 | score: 12.0 | score max : 53.0 | score avg: 14.6 | memory length: 100000 | epsilon: 0.383 | q avg : 0.21 | avg loss : 0.00
# episode:   149 | score:  9.0 | score max : 53.0 | score avg: 14.0 | memory length: 100000 | epsilon: 0.383 | q avg : 0.21 | avg loss : 0.00
# episode:   150 | score: 13.0 | score max : 53.0 | score avg: 13.9 | memory length: 100000 | epsilon: 0.380 | q avg : 0.21 | avg loss : 0.00
# episode:   151 | score: 21.0 | score max : 53.0 | score avg: 14.6 | memory length: 100000 | epsilon: 0.379 | q avg : 0.21 | avg loss : 0.00
# episode:   152 | score: 14.0 | score max : 53.0 | score avg: 14.6 | memory length: 100000 | epsilon: 0.377 | q avg : 0.22 | avg loss : 0.00
# episode:   153 | score: 23.0 | score max : 53.0 | score avg: 15.4 | memory length: 100000 | epsilon: 0.375 | q avg : 0.22 | avg loss : 0.00
# episode:   154 | score: 26.0 | score max : 53.0 | score avg: 16.5 | memory length: 100000 | epsilon: 0.374 | q avg : 0.22 | avg loss : 0.00
# episode:   155 | score: 11.0 | score max : 53.0 | score avg: 15.9 | memory length: 100000 | epsilon: 0.372 | q avg : 0.21 | avg loss : 0.00
# episode:   156 | score: 24.0 | score max : 53.0 | score avg: 16.7 | memory length: 100000 | epsilon: 0.370 | q avg : 0.22 | avg loss : 0.00
# episode:   157 | score:  7.0 | score max : 53.0 | score avg: 15.8 | memory length: 100000 | epsilon: 0.369 | q avg : 0.22 | avg loss : 0.00
# episode:   158 | score: 13.0 | score max : 53.0 | score avg: 15.5 | memory length: 100000 | epsilon: 0.368 | q avg : 0.22 | avg loss : 0.00
# episode:   159 | score: 26.0 | score max : 53.0 | score avg: 16.5 | memory length: 100000 | epsilon: 0.366 | q avg : 0.22 | avg loss : 0.00
# episode:   160 | score: 13.0 | score max : 53.0 | score avg: 16.2 | memory length: 100000 | epsilon: 0.364 | q avg : 0.23 | avg loss : 0.00
# episode:   161 | score: 27.0 | score max : 53.0 | score avg: 17.3 | memory length: 100000 | epsilon: 0.363 | q avg : 0.23 | avg loss : 0.00
# episode:   162 | score: 14.0 | score max : 53.0 | score avg: 16.9 | memory length: 100000 | epsilon: 0.362 | q avg : 0.23 | avg loss : 0.00
# episode:   163 | score:  8.0 | score max : 53.0 | score avg: 16.0 | memory length: 100000 | epsilon: 0.361 | q avg : 0.23 | avg loss : 0.00
# episode:   164 | score:  8.0 | score max : 53.0 | score avg: 15.2 | memory length: 100000 | epsilon: 0.359 | q avg : 0.23 | avg loss : 0.00
# episode:   165 | score: 18.0 | score max : 53.0 | score avg: 15.5 | memory length: 100000 | epsilon: 0.358 | q avg : 0.23 | avg loss : 0.00
# episode:   166 | score: 15.0 | score max : 53.0 | score avg: 15.5 | memory length: 100000 | epsilon: 0.356 | q avg : 0.23 | avg loss : 0.00
# episode:   167 | score: 22.0 | score max : 53.0 | score avg: 16.1 | memory length: 100000 | epsilon: 0.353 | q avg : 0.23 | avg loss : 0.00
# episode:   168 | score: 20.0 | score max : 53.0 | score avg: 16.5 | memory length: 100000 | epsilon: 0.352 | q avg : 0.23 | avg loss : 0.00
# episode:   169 | score: 16.0 | score max : 53.0 | score avg: 16.5 | memory length: 100000 | epsilon: 0.350 | q avg : 0.25 | avg loss : 0.00
# episode:   170 | score: 20.0 | score max : 53.0 | score avg: 16.8 | memory length: 100000 | epsilon: 0.349 | q avg : 0.24 | avg loss : 0.00
# episode:   171 | score: 14.0 | score max : 53.0 | score avg: 16.5 | memory length: 100000 | epsilon: 0.347 | q avg : 0.24 | avg loss : 0.00
# episode:   172 | score: 36.0 | score max : 53.0 | score avg: 18.5 | memory length: 100000 | epsilon: 0.345 | q avg : 0.24 | avg loss : 0.00
# episode:   173 | score: 20.0 | score max : 53.0 | score avg: 18.6 | memory length: 100000 | epsilon: 0.344 | q avg : 0.26 | avg loss : 0.00
# episode:   174 | score: 17.0 | score max : 53.0 | score avg: 18.5 | memory length: 100000 | epsilon: 0.342 | q avg : 0.25 | avg loss : 0.00
# episode:   175 | score: 12.0 | score max : 53.0 | score avg: 17.8 | memory length: 100000 | epsilon: 0.341 | q avg : 0.26 | avg loss : 0.00
# episode:   176 | score: 22.0 | score max : 53.0 | score avg: 18.2 | memory length: 100000 | epsilon: 0.339 | q avg : 0.25 | avg loss : 0.00
# episode:   177 | score: 42.0 | score max : 53.0 | score avg: 20.6 | memory length: 100000 | epsilon: 0.337 | q avg : 0.25 | avg loss : 0.00
# episode:   178 | score: 31.0 | score max : 53.0 | score avg: 21.7 | memory length: 100000 | epsilon: 0.335 | q avg : 0.25 | avg loss : 0.00
# episode:   179 | score: 24.0 | score max : 53.0 | score avg: 21.9 | memory length: 100000 | epsilon: 0.334 | q avg : 0.25 | avg loss : 0.00
# episode:   180 | score: 15.0 | score max : 53.0 | score avg: 21.2 | memory length: 100000 | epsilon: 0.332 | q avg : 0.25 | avg loss : 0.00
# episode:   181 | score: 28.0 | score max : 53.0 | score avg: 21.9 | memory length: 100000 | epsilon: 0.330 | q avg : 0.25 | avg loss : 0.00
# episode:   182 | score: 24.0 | score max : 53.0 | score avg: 22.1 | memory length: 100000 | epsilon: 0.328 | q avg : 0.26 | avg loss : 0.00
# episode:   183 | score: 25.0 | score max : 53.0 | score avg: 22.4 | memory length: 100000 | epsilon: 0.327 | q avg : 0.25 | avg loss : 0.00
# episode:   184 | score: 33.0 | score max : 53.0 | score avg: 23.4 | memory length: 100000 | epsilon: 0.325 | q avg : 0.26 | avg loss : 0.00
# episode:   185 | score: 26.0 | score max : 53.0 | score avg: 23.7 | memory length: 100000 | epsilon: 0.324 | q avg : 0.26 | avg loss : 0.00
# episode:   186 | score: 17.0 | score max : 53.0 | score avg: 23.0 | memory length: 100000 | epsilon: 0.321 | q avg : 0.26 | avg loss : 0.00
# episode:   187 | score: 16.0 | score max : 53.0 | score avg: 22.3 | memory length: 100000 | epsilon: 0.320 | q avg : 0.26 | avg loss : 0.00
# episode:   188 | score: 18.0 | score max : 53.0 | score avg: 21.9 | memory length: 100000 | epsilon: 0.318 | q avg : 0.26 | avg loss : 0.00
# episode:   189 | score: 13.0 | score max : 53.0 | score avg: 21.0 | memory length: 100000 | epsilon: 0.316 | q avg : 0.26 | avg loss : 0.00
# episode:   190 | score: 30.0 | score max : 53.0 | score avg: 21.9 | memory length: 100000 | epsilon: 0.313 | q avg : 0.27 | avg loss : 0.00
# episode:   191 | score: 17.0 | score max : 53.0 | score avg: 21.4 | memory length: 100000 | epsilon: 0.312 | q avg : 0.27 | avg loss : 0.00
# episode:   192 | score: 21.0 | score max : 53.0 | score avg: 21.4 | memory length: 100000 | epsilon: 0.310 | q avg : 0.27 | avg loss : 0.00
# episode:   193 | score: 25.0 | score max : 53.0 | score avg: 21.7 | memory length: 100000 | epsilon: 0.308 | q avg : 0.27 | avg loss : 0.00
# episode:   194 | score: 27.0 | score max : 53.0 | score avg: 22.3 | memory length: 100000 | epsilon: 0.307 | q avg : 0.27 | avg loss : 0.00
# episode:   195 | score: 17.0 | score max : 53.0 | score avg: 21.7 | memory length: 100000 | epsilon: 0.304 | q avg : 0.28 | avg loss : 0.00
# episode:   196 | score: 15.0 | score max : 53.0 | score avg: 21.1 | memory length: 100000 | epsilon: 0.303 | q avg : 0.28 | avg loss : 0.00
# episode:   197 | score: 19.0 | score max : 53.0 | score avg: 20.9 | memory length: 100000 | epsilon: 0.302 | q avg : 0.28 | avg loss : 0.00
# episode:   198 | score: 30.0 | score max : 53.0 | score avg: 21.8 | memory length: 100000 | epsilon: 0.301 | q avg : 0.28 | avg loss : 0.00
# episode:   199 | score: 16.0 | score max : 53.0 | score avg: 21.2 | memory length: 100000 | epsilon: 0.299 | q avg : 0.28 | avg loss : 0.00
# episode:   200 | score: 29.0 | score max : 53.0 | score avg: 22.0 | memory length: 100000 | epsilon: 0.298 | q avg : 0.28 | avg loss : 0.00
# episode:   201 | score: 19.0 | score max : 53.0 | score avg: 21.7 | memory length: 100000 | epsilon: 0.296 | q avg : 0.28 | avg loss : 0.00
# episode:   202 | score: 27.0 | score max : 53.0 | score avg: 22.2 | memory length: 100000 | epsilon: 0.295 | q avg : 0.28 | avg loss : 0.00
# episode:   203 | score: 34.0 | score max : 53.0 | score avg: 23.4 | memory length: 100000 | epsilon: 0.293 | q avg : 0.28 | avg loss : 0.00
# episode:   204 | score: 19.0 | score max : 53.0 | score avg: 22.9 | memory length: 100000 | epsilon: 0.292 | q avg : 0.29 | avg loss : 0.00
# episode:   205 | score: 80.0 | score max : 80.0 | score avg: 28.7 | memory length: 100000 | epsilon: 0.290 | q avg : 0.28 | avg loss : 0.00
# episode:   206 | score: 27.0 | score max : 80.0 | score avg: 28.5 | memory length: 100000 | epsilon: 0.288 | q avg : 0.29 | avg loss : 0.00
# episode:   207 | score: 28.0 | score max : 80.0 | score avg: 28.4 | memory length: 100000 | epsilon: 0.286 | q avg : 0.29 | avg loss : 0.00
# episode:   208 | score: 18.0 | score max : 80.0 | score avg: 27.4 | memory length: 100000 | epsilon: 0.284 | q avg : 0.29 | avg loss : 0.00
# episode:   209 | score: 22.0 | score max : 80.0 | score avg: 26.9 | memory length: 100000 | epsilon: 0.283 | q avg : 0.29 | avg loss : 0.00
# episode:   210 | score: 28.0 | score max : 80.0 | score avg: 27.0 | memory length: 100000 | epsilon: 0.282 | q avg : 0.29 | avg loss : 0.00
# episode:   211 | score: 24.0 | score max : 80.0 | score avg: 26.7 | memory length: 100000 | epsilon: 0.280 | q avg : 0.29 | avg loss : 0.00
# episode:   212 | score: 27.0 | score max : 80.0 | score avg: 26.7 | memory length: 100000 | epsilon: 0.279 | q avg : 0.30 | avg loss : 0.00
# episode:   213 | score:  7.0 | score max : 80.0 | score avg: 24.7 | memory length: 100000 | epsilon: 0.278 | q avg : 0.29 | avg loss : 0.00
# episode:   214 | score: 39.0 | score max : 80.0 | score avg: 26.2 | memory length: 100000 | epsilon: 0.277 | q avg : 0.29 | avg loss : 0.00
# episode:   215 | score: 27.0 | score max : 80.0 | score avg: 26.2 | memory length: 100000 | epsilon: 0.275 | q avg : 0.29 | avg loss : 0.00
# episode:   216 | score: 30.0 | score max : 80.0 | score avg: 26.6 | memory length: 100000 | epsilon: 0.274 | q avg : 0.29 | avg loss : 0.00
# episode:   217 | score: 14.0 | score max : 80.0 | score avg: 25.4 | memory length: 100000 | epsilon: 0.273 | q avg : 0.30 | avg loss : 0.00
# episode:   218 | score: 18.0 | score max : 80.0 | score avg: 24.6 | memory length: 100000 | epsilon: 0.271 | q avg : 0.29 | avg loss : 0.00
# episode:   219 | score: 27.0 | score max : 80.0 | score avg: 24.9 | memory length: 100000 | epsilon: 0.269 | q avg : 0.30 | avg loss : 0.00
# episode:   220 | score: 23.0 | score max : 80.0 | score avg: 24.7 | memory length: 100000 | epsilon: 0.268 | q avg : 0.30 | avg loss : 0.00
# episode:   221 | score: 31.0 | score max : 80.0 | score avg: 25.3 | memory length: 100000 | epsilon: 0.266 | q avg : 0.30 | avg loss : 0.00
# episode:   222 | score: 11.0 | score max : 80.0 | score avg: 23.9 | memory length: 100000 | epsilon: 0.266 | q avg : 0.30 | avg loss : 0.00
# episode:   223 | score: 40.0 | score max : 80.0 | score avg: 25.5 | memory length: 100000 | epsilon: 0.264 | q avg : 0.31 | avg loss : 0.00
# episode:   224 | score: 20.0 | score max : 80.0 | score avg: 24.9 | memory length: 100000 | epsilon: 0.264 | q avg : 0.30 | avg loss : 0.00
# episode:   225 | score: 32.0 | score max : 80.0 | score avg: 25.6 | memory length: 100000 | epsilon: 0.262 | q avg : 0.30 | avg loss : 0.00
# episode:   226 | score: 19.0 | score max : 80.0 | score avg: 25.0 | memory length: 100000 | epsilon: 0.261 | q avg : 0.30 | avg loss : 0.00
# episode:   227 | score: 19.0 | score max : 80.0 | score avg: 24.4 | memory length: 100000 | epsilon: 0.260 | q avg : 0.31 | avg loss : 0.00
# episode:   228 | score: 15.0 | score max : 80.0 | score avg: 23.4 | memory length: 100000 | epsilon: 0.259 | q avg : 0.31 | avg loss : 0.00
# episode:   229 | score: 24.0 | score max : 80.0 | score avg: 23.5 | memory length: 100000 | epsilon: 0.257 | q avg : 0.31 | avg loss : 0.00
# episode:   230 | score: 32.0 | score max : 80.0 | score avg: 24.4 | memory length: 100000 | epsilon: 0.255 | q avg : 0.31 | avg loss : 0.00
# episode:   231 | score: 32.0 | score max : 80.0 | score avg: 25.1 | memory length: 100000 | epsilon: 0.254 | q avg : 0.31 | avg loss : 0.00
# episode:   232 | score: 36.0 | score max : 80.0 | score avg: 26.2 | memory length: 100000 | epsilon: 0.253 | q avg : 0.31 | avg loss : 0.00
# episode:   233 | score: 28.0 | score max : 80.0 | score avg: 26.4 | memory length: 100000 | epsilon: 0.253 | q avg : 0.31 | avg loss : 0.00
# episode:   234 | score: 29.0 | score max : 80.0 | score avg: 26.6 | memory length: 100000 | epsilon: 0.252 | q avg : 0.31 | avg loss : 0.00
# episode:   235 | score: 38.0 | score max : 80.0 | score avg: 27.8 | memory length: 100000 | epsilon: 0.250 | q avg : 0.32 | avg loss : 0.00
# episode:   236 | score: 38.0 | score max : 80.0 | score avg: 28.8 | memory length: 100000 | epsilon: 0.248 | q avg : 0.31 | avg loss : 0.00
# episode:   237 | score: 36.0 | score max : 80.0 | score avg: 29.5 | memory length: 100000 | epsilon: 0.247 | q avg : 0.32 | avg loss : 0.00
# episode:   238 | score: 14.0 | score max : 80.0 | score avg: 28.0 | memory length: 100000 | epsilon: 0.246 | q avg : 0.32 | avg loss : 0.00
# episode:   239 | score: 30.0 | score max : 80.0 | score avg: 28.2 | memory length: 100000 | epsilon: 0.245 | q avg : 0.32 | avg loss : 0.00
# episode:   240 | score: 28.0 | score max : 80.0 | score avg: 28.2 | memory length: 100000 | epsilon: 0.244 | q avg : 0.32 | avg loss : 0.00
# episode:   241 | score: 14.0 | score max : 80.0 | score avg: 26.7 | memory length: 100000 | epsilon: 0.242 | q avg : 0.32 | avg loss : 0.00
# episode:   242 | score: 28.0 | score max : 80.0 | score avg: 26.9 | memory length: 100000 | epsilon: 0.241 | q avg : 0.33 | avg loss : 0.00
# episode:   243 | score: 32.0 | score max : 80.0 | score avg: 27.4 | memory length: 100000 | epsilon: 0.240 | q avg : 0.33 | avg loss : 0.00
# episode:   244 | score: 31.0 | score max : 80.0 | score avg: 27.7 | memory length: 100000 | epsilon: 0.239 | q avg : 0.32 | avg loss : 0.00
# episode:   245 | score: 17.0 | score max : 80.0 | score avg: 26.7 | memory length: 100000 | epsilon: 0.239 | q avg : 0.32 | avg loss : 0.00
# episode:   246 | score: 26.0 | score max : 80.0 | score avg: 26.6 | memory length: 100000 | epsilon: 0.237 | q avg : 0.32 | avg loss : 0.00
# episode:   247 | score: 39.0 | score max : 80.0 | score avg: 27.8 | memory length: 100000 | epsilon: 0.236 | q avg : 0.32 | avg loss : 0.00
# episode:   248 | score: 29.0 | score max : 80.0 | score avg: 28.0 | memory length: 100000 | epsilon: 0.235 | q avg : 0.32 | avg loss : 0.00
# episode:   249 | score: 17.0 | score max : 80.0 | score avg: 26.9 | memory length: 100000 | epsilon: 0.233 | q avg : 0.33 | avg loss : 0.00
# episode:   250 | score: 35.0 | score max : 80.0 | score avg: 27.7 | memory length: 100000 | epsilon: 0.232 | q avg : 0.33 | avg loss : 0.00
# episode:   251 | score: 43.0 | score max : 80.0 | score avg: 29.2 | memory length: 100000 | epsilon: 0.230 | q avg : 0.33 | avg loss : 0.00
# episode:   252 | score: 25.0 | score max : 80.0 | score avg: 28.8 | memory length: 100000 | epsilon: 0.229 | q avg : 0.34 | avg loss : 0.00
# episode:   253 | score: 28.0 | score max : 80.0 | score avg: 28.7 | memory length: 100000 | epsilon: 0.228 | q avg : 0.33 | avg loss : 0.00
# episode:   254 | score: 39.0 | score max : 80.0 | score avg: 29.7 | memory length: 100000 | epsilon: 0.227 | q avg : 0.33 | avg loss : 0.00
# episode:   255 | score: 20.0 | score max : 80.0 | score avg: 28.8 | memory length: 100000 | epsilon: 0.226 | q avg : 0.33 | avg loss : 0.00
# episode:   256 | score: 33.0 | score max : 80.0 | score avg: 29.2 | memory length: 100000 | epsilon: 0.225 | q avg : 0.35 | avg loss : 0.00
# episode:   257 | score: 40.0 | score max : 80.0 | score avg: 30.3 | memory length: 100000 | epsilon: 0.224 | q avg : 0.35 | avg loss : 0.00
# episode:   258 | score: 33.0 | score max : 80.0 | score avg: 30.5 | memory length: 100000 | epsilon: 0.224 | q avg : 0.34 | avg loss : 0.00
# episode:   259 | score: 38.0 | score max : 80.0 | score avg: 31.3 | memory length: 100000 | epsilon: 0.223 | q avg : 0.34 | avg loss : 0.00
# episode:   260 | score: 29.0 | score max : 80.0 | score avg: 31.1 | memory length: 100000 | epsilon: 0.222 | q avg : 0.34 | avg loss : 0.00
# episode:   261 | score: 27.0 | score max : 80.0 | score avg: 30.7 | memory length: 100000 | epsilon: 0.221 | q avg : 0.34 | avg loss : 0.00
# episode:   262 | score: 24.0 | score max : 80.0 | score avg: 30.0 | memory length: 100000 | epsilon: 0.219 | q avg : 0.34 | avg loss : 0.00
# episode:   263 | score: 20.0 | score max : 80.0 | score avg: 29.0 | memory length: 100000 | epsilon: 0.218 | q avg : 0.34 | avg loss : 0.00
# episode:   264 | score: 25.0 | score max : 80.0 | score avg: 28.6 | memory length: 100000 | epsilon: 0.217 | q avg : 0.34 | avg loss : 0.00
# episode:   265 | score: 26.0 | score max : 80.0 | score avg: 28.3 | memory length: 100000 | epsilon: 0.216 | q avg : 0.35 | avg loss : 0.00
# episode:   266 | score: 37.0 | score max : 80.0 | score avg: 29.2 | memory length: 100000 | epsilon: 0.215 | q avg : 0.35 | avg loss : 0.00
# episode:   267 | score: 36.0 | score max : 80.0 | score avg: 29.9 | memory length: 100000 | epsilon: 0.213 | q avg : 0.35 | avg loss : 0.00
# episode:   268 | score: 40.0 | score max : 80.0 | score avg: 30.9 | memory length: 100000 | epsilon: 0.212 | q avg : 0.35 | avg loss : 0.00
# episode:   269 | score: 16.0 | score max : 80.0 | score avg: 29.4 | memory length: 100000 | epsilon: 0.212 | q avg : 0.35 | avg loss : 0.00
# episode:   270 | score: 25.0 | score max : 80.0 | score avg: 29.0 | memory length: 100000 | epsilon: 0.211 | q avg : 0.35 | avg loss : 0.00
# episode:   271 | score: 18.0 | score max : 80.0 | score avg: 27.9 | memory length: 100000 | epsilon: 0.210 | q avg : 0.36 | avg loss : 0.00
# episode:   272 | score: 30.0 | score max : 80.0 | score avg: 28.1 | memory length: 100000 | epsilon: 0.209 | q avg : 0.35 | avg loss : 0.00
# episode:   273 | score: 38.0 | score max : 80.0 | score avg: 29.1 | memory length: 100000 | epsilon: 0.208 | q avg : 0.35 | avg loss : 0.00
# episode:   274 | score: 17.0 | score max : 80.0 | score avg: 27.9 | memory length: 100000 | epsilon: 0.208 | q avg : 0.35 | avg loss : 0.00
# episode:   275 | score: 13.0 | score max : 80.0 | score avg: 26.4 | memory length: 100000 | epsilon: 0.206 | q avg : 0.36 | avg loss : 0.00
# episode:   276 | score: 15.0 | score max : 80.0 | score avg: 25.2 | memory length: 100000 | epsilon: 0.205 | q avg : 0.36 | avg loss : 0.00
# episode:   277 | score: 42.0 | score max : 80.0 | score avg: 26.9 | memory length: 100000 | epsilon: 0.205 | q avg : 0.37 | avg loss : 0.00
# episode:   278 | score: 50.0 | score max : 80.0 | score avg: 29.2 | memory length: 100000 | epsilon: 0.203 | q avg : 0.36 | avg loss : 0.00
# episode:   279 | score: 37.0 | score max : 80.0 | score avg: 30.0 | memory length: 100000 | epsilon: 0.202 | q avg : 0.38 | avg loss : 0.00
# episode:   280 | score: 39.0 | score max : 80.0 | score avg: 30.9 | memory length: 100000 | epsilon: 0.201 | q avg : 0.36 | avg loss : 0.00
# episode:   281 | score: 45.0 | score max : 80.0 | score avg: 32.3 | memory length: 100000 | epsilon: 0.200 | q avg : 0.36 | avg loss : 0.00
# episode:   282 | score: 37.0 | score max : 80.0 | score avg: 32.8 | memory length: 100000 | epsilon: 0.199 | q avg : 0.36 | avg loss : 0.00
# episode:   283 | score: 23.0 | score max : 80.0 | score avg: 31.8 | memory length: 100000 | epsilon: 0.198 | q avg : 0.36 | avg loss : 0.00
# episode:   284 | score: 44.0 | score max : 80.0 | score avg: 33.0 | memory length: 100000 | epsilon: 0.196 | q avg : 0.37 | avg loss : 0.00
# episode:   285 | score: 25.0 | score max : 80.0 | score avg: 32.2 | memory length: 100000 | epsilon: 0.195 | q avg : 0.38 | avg loss : 0.00
# episode:   286 | score: 42.0 | score max : 80.0 | score avg: 33.2 | memory length: 100000 | epsilon: 0.194 | q avg : 0.36 | avg loss : 0.00
# episode:   287 | score: 37.0 | score max : 80.0 | score avg: 33.6 | memory length: 100000 | epsilon: 0.193 | q avg : 0.37 | avg loss : 0.00
# episode:   288 | score: 32.0 | score max : 80.0 | score avg: 33.4 | memory length: 100000 | epsilon: 0.191 | q avg : 0.36 | avg loss : 0.00
# episode:   289 | score: 44.0 | score max : 80.0 | score avg: 34.5 | memory length: 100000 | epsilon: 0.191 | q avg : 0.36 | avg loss : 0.00
# episode:   290 | score: 21.0 | score max : 80.0 | score avg: 33.1 | memory length: 100000 | epsilon: 0.189 | q avg : 0.37 | avg loss : 0.00
# episode:   291 | score: 25.0 | score max : 80.0 | score avg: 32.3 | memory length: 100000 | epsilon: 0.188 | q avg : 0.38 | avg loss : 0.00
# episode:   292 | score: 44.0 | score max : 80.0 | score avg: 33.5 | memory length: 100000 | epsilon: 0.187 | q avg : 0.38 | avg loss : 0.00
# episode:   293 | score: 27.0 | score max : 80.0 | score avg: 32.8 | memory length: 100000 | epsilon: 0.186 | q avg : 0.38 | avg loss : 0.00
# episode:   294 | score: 38.0 | score max : 80.0 | score avg: 33.4 | memory length: 100000 | epsilon: 0.185 | q avg : 0.38 | avg loss : 0.00
# episode:   295 | score: 32.0 | score max : 80.0 | score avg: 33.2 | memory length: 100000 | epsilon: 0.184 | q avg : 0.38 | avg loss : 0.00
# episode:   296 | score: 21.0 | score max : 80.0 | score avg: 32.0 | memory length: 100000 | epsilon: 0.183 | q avg : 0.38 | avg loss : 0.00
# episode:   297 | score: 38.0 | score max : 80.0 | score avg: 32.6 | memory length: 100000 | epsilon: 0.182 | q avg : 0.38 | avg loss : 0.00
# episode:   298 | score: 29.0 | score max : 80.0 | score avg: 32.2 | memory length: 100000 | epsilon: 0.181 | q avg : 0.40 | avg loss : 0.00
# episode:   299 | score: 16.0 | score max : 80.0 | score avg: 30.6 | memory length: 100000 | epsilon: 0.179 | q avg : 0.39 | avg loss : 0.00
# episode:   300 | score: 38.0 | score max : 80.0 | score avg: 31.4 | memory length: 100000 | epsilon: 0.178 | q avg : 0.39 | avg loss : 0.00
# episode:   301 | score: 37.0 | score max : 80.0 | score avg: 31.9 | memory length: 100000 | epsilon: 0.177 | q avg : 0.39 | avg loss : 0.00
# episode:   302 | score: 20.0 | score max : 80.0 | score avg: 30.7 | memory length: 100000 | epsilon: 0.176 | q avg : 0.39 | avg loss : 0.00
# episode:   303 | score: 28.0 | score max : 80.0 | score avg: 30.5 | memory length: 100000 | epsilon: 0.176 | q avg : 0.39 | avg loss : 0.00
# episode:   304 | score: 60.0 | score max : 80.0 | score avg: 33.4 | memory length: 100000 | epsilon: 0.175 | q avg : 0.39 | avg loss : 0.00
# episode:   305 | score: 28.0 | score max : 80.0 | score avg: 32.9 | memory length: 100000 | epsilon: 0.174 | q avg : 0.40 | avg loss : 0.00
# episode:   306 | score: 55.0 | score max : 80.0 | score avg: 35.1 | memory length: 100000 | epsilon: 0.173 | q avg : 0.39 | avg loss : 0.00
# episode:   307 | score: 39.0 | score max : 80.0 | score avg: 35.5 | memory length: 100000 | epsilon: 0.171 | q avg : 0.39 | avg loss : 0.00
# episode:   308 | score: 28.0 | score max : 80.0 | score avg: 34.7 | memory length: 100000 | epsilon: 0.171 | q avg : 0.39 | avg loss : 0.00
# episode:   309 | score: 28.0 | score max : 80.0 | score avg: 34.1 | memory length: 100000 | epsilon: 0.170 | q avg : 0.40 | avg loss : 0.00
# episode:   310 | score: 49.0 | score max : 80.0 | score avg: 35.5 | memory length: 100000 | epsilon: 0.168 | q avg : 0.40 | avg loss : 0.00
# episode:   311 | score: 26.0 | score max : 80.0 | score avg: 34.6 | memory length: 100000 | epsilon: 0.167 | q avg : 0.41 | avg loss : 0.00
# episode:   312 | score: 44.0 | score max : 80.0 | score avg: 35.5 | memory length: 100000 | epsilon: 0.166 | q avg : 0.40 | avg loss : 0.00
# episode:   313 | score: 42.0 | score max : 80.0 | score avg: 36.2 | memory length: 100000 | epsilon: 0.165 | q avg : 0.39 | avg loss : 0.00
# episode:   314 | score: 34.0 | score max : 80.0 | score avg: 36.0 | memory length: 100000 | epsilon: 0.164 | q avg : 0.40 | avg loss : 0.00
# episode:   315 | score: 36.0 | score max : 80.0 | score avg: 36.0 | memory length: 100000 | epsilon: 0.163 | q avg : 0.41 | avg loss : 0.00
# episode:   316 | score: 48.0 | score max : 80.0 | score avg: 37.2 | memory length: 100000 | epsilon: 0.161 | q avg : 0.40 | avg loss : 0.00
# episode:   317 | score: 26.0 | score max : 80.0 | score avg: 36.1 | memory length: 100000 | epsilon: 0.160 | q avg : 0.41 | avg loss : 0.00
# episode:   318 | score: 44.0 | score max : 80.0 | score avg: 36.8 | memory length: 100000 | epsilon: 0.159 | q avg : 0.41 | avg loss : 0.00
# episode:   319 | score: 53.0 | score max : 80.0 | score avg: 38.5 | memory length: 100000 | epsilon: 0.158 | q avg : 0.41 | avg loss : 0.00
# episode:   320 | score: 62.0 | score max : 80.0 | score avg: 40.8 | memory length: 100000 | epsilon: 0.158 | q avg : 0.40 | avg loss : 0.00
# episode:   321 | score: 45.0 | score max : 80.0 | score avg: 41.2 | memory length: 100000 | epsilon: 0.157 | q avg : 0.42 | avg loss : 0.00
# episode:   322 | score: 32.0 | score max : 80.0 | score avg: 40.3 | memory length: 100000 | epsilon: 0.157 | q avg : 0.40 | avg loss : 0.00
# episode:   323 | score: 47.0 | score max : 80.0 | score avg: 41.0 | memory length: 100000 | epsilon: 0.155 | q avg : 0.41 | avg loss : 0.00
# episode:   324 | score: 42.0 | score max : 80.0 | score avg: 41.1 | memory length: 100000 | epsilon: 0.154 | q avg : 0.41 | avg loss : 0.00
# episode:   325 | score: 48.0 | score max : 80.0 | score avg: 41.8 | memory length: 100000 | epsilon: 0.153 | q avg : 0.41 | avg loss : 0.00
# episode:   326 | score: 37.0 | score max : 80.0 | score avg: 41.3 | memory length: 100000 | epsilon: 0.152 | q avg : 0.42 | avg loss : 0.00
# episode:   327 | score: 41.0 | score max : 80.0 | score avg: 41.3 | memory length: 100000 | epsilon: 0.150 | q avg : 0.42 | avg loss : 0.00
# episode:   328 | score: 58.0 | score max : 80.0 | score avg: 42.9 | memory length: 100000 | epsilon: 0.149 | q avg : 0.42 | avg loss : 0.00
# episode:   329 | score: 31.0 | score max : 80.0 | score avg: 41.7 | memory length: 100000 | epsilon: 0.149 | q avg : 0.42 | avg loss : 0.00
# episode:   330 | score: 36.0 | score max : 80.0 | score avg: 41.2 | memory length: 100000 | epsilon: 0.147 | q avg : 0.42 | avg loss : 0.00
# episode:   331 | score: 53.0 | score max : 80.0 | score avg: 42.4 | memory length: 100000 | epsilon: 0.147 | q avg : 0.42 | avg loss : 0.00
# episode:   332 | score: 32.0 | score max : 80.0 | score avg: 41.3 | memory length: 100000 | epsilon: 0.146 | q avg : 0.42 | avg loss : 0.00
# episode:   333 | score: 42.0 | score max : 80.0 | score avg: 41.4 | memory length: 100000 | epsilon: 0.145 | q avg : 0.42 | avg loss : 0.00
# episode:   334 | score: 31.0 | score max : 80.0 | score avg: 40.3 | memory length: 100000 | epsilon: 0.144 | q avg : 0.43 | avg loss : 0.00
# episode:   335 | score: 17.0 | score max : 80.0 | score avg: 38.0 | memory length: 100000 | epsilon: 0.143 | q avg : 0.43 | avg loss : 0.00
# episode:   336 | score: 35.0 | score max : 80.0 | score avg: 37.7 | memory length: 100000 | epsilon: 0.142 | q avg : 0.44 | avg loss : 0.01
# episode:   337 | score: 46.0 | score max : 80.0 | score avg: 38.5 | memory length: 100000 | epsilon: 0.141 | q avg : 0.43 | avg loss : 0.00
# episode:   338 | score: 53.0 | score max : 80.0 | score avg: 40.0 | memory length: 100000 | epsilon: 0.140 | q avg : 0.43 | avg loss : 0.00
# episode:   339 | score: 40.0 | score max : 80.0 | score avg: 40.0 | memory length: 100000 | epsilon: 0.139 | q avg : 0.43 | avg loss : 0.00
# episode:   340 | score: 30.0 | score max : 80.0 | score avg: 39.0 | memory length: 100000 | epsilon: 0.138 | q avg : 0.43 | avg loss : 0.01
# episode:   341 | score: 21.0 | score max : 80.0 | score avg: 37.2 | memory length: 100000 | epsilon: 0.138 | q avg : 0.43 | avg loss : 0.00
# ...
# episode:  4916 | score: 46.0 | score max : 113.0 | score avg: 54.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4917 | score: 74.0 | score max : 113.0 | score avg: 56.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4918 | score: 83.0 | score max : 113.0 | score avg: 58.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4919 | score: 63.0 | score max : 113.0 | score avg: 59.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4920 | score: 72.0 | score max : 113.0 | score avg: 60.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4921 | score: 28.0 | score max : 113.0 | score avg: 57.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4922 | score: 68.0 | score max : 113.0 | score avg: 58.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4923 | score: 40.0 | score max : 113.0 | score avg: 56.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4924 | score: 51.0 | score max : 113.0 | score avg: 55.9 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4925 | score: 54.0 | score max : 113.0 | score avg: 55.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4926 | score: 33.0 | score max : 113.0 | score avg: 53.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.00
# episode:  4927 | score: 43.0 | score max : 113.0 | score avg: 52.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4928 | score: 59.0 | score max : 113.0 | score avg: 53.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.00
# episode:  4929 | score: 43.0 | score max : 113.0 | score avg: 52.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.00
# episode:  4930 | score: 38.0 | score max : 113.0 | score avg: 50.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4931 | score: 40.0 | score max : 113.0 | score avg: 49.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4932 | score: 34.0 | score max : 113.0 | score avg: 48.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4933 | score: 40.0 | score max : 113.0 | score avg: 47.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4934 | score: 38.0 | score max : 113.0 | score avg: 46.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4935 | score: 50.0 | score max : 113.0 | score avg: 46.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4936 | score: 48.0 | score max : 113.0 | score avg: 46.8 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4937 | score: 60.0 | score max : 113.0 | score avg: 48.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4938 | score: 56.0 | score max : 113.0 | score avg: 48.9 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4939 | score: 41.0 | score max : 113.0 | score avg: 48.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.00
# episode:  4940 | score: 56.0 | score max : 113.0 | score avg: 48.9 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4941 | score: 31.0 | score max : 113.0 | score avg: 47.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.00
# episode:  4942 | score: 49.0 | score max : 113.0 | score avg: 47.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4943 | score: 37.0 | score max : 113.0 | score avg: 46.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4944 | score: 31.0 | score max : 113.0 | score avg: 44.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4945 | score: 33.0 | score max : 113.0 | score avg: 43.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4946 | score: 47.0 | score max : 113.0 | score avg: 43.9 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4947 | score: 68.0 | score max : 113.0 | score avg: 46.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4948 | score: 79.0 | score max : 113.0 | score avg: 49.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4949 | score: 59.0 | score max : 113.0 | score avg: 50.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.89 | avg loss : 0.01
# episode:  4950 | score: 72.0 | score max : 113.0 | score avg: 52.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4951 | score: 63.0 | score max : 113.0 | score avg: 53.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4952 | score: 46.0 | score max : 113.0 | score avg: 52.9 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4953 | score: 58.0 | score max : 113.0 | score avg: 53.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4954 | score: 55.0 | score max : 113.0 | score avg: 53.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4955 | score: 22.0 | score max : 113.0 | score avg: 50.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4956 | score: 59.0 | score max : 113.0 | score avg: 51.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.00
# episode:  4957 | score: 29.0 | score max : 113.0 | score avg: 49.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.00
# episode:  4958 | score: 35.0 | score max : 113.0 | score avg: 47.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4959 | score: 76.0 | score max : 113.0 | score avg: 50.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4960 | score: 71.0 | score max : 113.0 | score avg: 52.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4961 | score: 72.0 | score max : 113.0 | score avg: 54.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4962 | score: 60.0 | score max : 113.0 | score avg: 55.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4963 | score: 49.0 | score max : 113.0 | score avg: 54.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4964 | score: 35.0 | score max : 113.0 | score avg: 52.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.00
# episode:  4965 | score: 42.0 | score max : 113.0 | score avg: 51.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4966 | score: 35.0 | score max : 113.0 | score avg: 49.8 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4967 | score: 48.0 | score max : 113.0 | score avg: 49.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4968 | score: 54.0 | score max : 113.0 | score avg: 50.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4969 | score: 31.0 | score max : 113.0 | score avg: 48.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  4970 | score: 54.0 | score max : 113.0 | score avg: 48.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4971 | score: 82.0 | score max : 113.0 | score avg: 52.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4972 | score: 51.0 | score max : 113.0 | score avg: 52.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4973 | score: 49.0 | score max : 113.0 | score avg: 51.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4974 | score: 41.0 | score max : 113.0 | score avg: 50.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4975 | score: 55.0 | score max : 113.0 | score avg: 51.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4976 | score: 55.0 | score max : 113.0 | score avg: 51.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4977 | score: 95.0 | score max : 113.0 | score avg: 55.8 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4978 | score: 43.0 | score max : 113.0 | score avg: 54.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4979 | score: 26.0 | score max : 113.0 | score avg: 51.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4980 | score: 36.0 | score max : 113.0 | score avg: 50.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4981 | score: 57.0 | score max : 113.0 | score avg: 50.8 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4982 | score: 43.0 | score max : 113.0 | score avg: 50.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4983 | score: 42.0 | score max : 113.0 | score avg: 49.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4984 | score: 51.0 | score max : 113.0 | score avg: 49.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4985 | score: 61.0 | score max : 113.0 | score avg: 50.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4986 | score: 52.0 | score max : 113.0 | score avg: 50.7 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4987 | score: 66.0 | score max : 113.0 | score avg: 52.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4988 | score: 24.0 | score max : 113.0 | score avg: 49.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.00
# episode:  4989 | score: 47.0 | score max : 113.0 | score avg: 49.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4990 | score: 30.0 | score max : 113.0 | score avg: 47.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4991 | score: 75.0 | score max : 113.0 | score avg: 50.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4992 | score: 46.0 | score max : 113.0 | score avg: 49.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4993 | score: 44.0 | score max : 113.0 | score avg: 49.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4994 | score: 91.0 | score max : 113.0 | score avg: 53.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4995 | score: 59.0 | score max : 113.0 | score avg: 53.8 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.00
# episode:  4996 | score: 37.0 | score max : 113.0 | score avg: 52.1 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4997 | score: 56.0 | score max : 113.0 | score avg: 52.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4998 | score: 49.0 | score max : 113.0 | score avg: 52.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  4999 | score: 46.0 | score max : 113.0 | score avg: 51.6 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.00
# episode:  5000 | score: 104.0 | score max : 113.0 | score avg: 56.8 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  5001 | score: 49.0 | score max : 113.0 | score avg: 56.0 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  5002 | score: 58.0 | score max : 113.0 | score avg: 56.2 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.01
# episode:  5003 | score: 77.0 | score max : 113.0 | score avg: 58.3 | memory length: 100000 | epsilon: 0.100 | q avg : 1.90 | avg loss : 0.00
# episode:  5004 | score: 14.0 | score max : 113.0 | score avg: 53.9 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  5005 | score: 40.0 | score max : 113.0 | score avg: 52.5 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# episode:  5006 | score: 52.0 | score max : 113.0 | score avg: 52.4 | memory length: 100000 | epsilon: 0.100 | q avg : 1.91 | avg loss : 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0ea54e4ba411> in <module>
#      34
#      35             # 바로 전 history를 입력으로 받아 행동을 선택
# ---> 36             action = agent.get_action(history)
#      37
#      38             # 선택한 행동으로 환경에서 한 타임스텝 진행
#
# <ipython-input-7-a9523529347a> in get_action(self, history)
#      49             return random.randrange(self.action_size)
#      50         else:
# ---> 51             q_value = self.model(history)
#      52             return np.argmax(q_value[0])
#      53
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# <ipython-input-6-cc419c805926> in call(self, x)
#      16         x = self.conv3(x)
#      17         x = self.flatten(x)
# ---> 18         x = self.fc(x)
#      19         q = self.fc_out(x)
#      20         return q
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\keras\layers\core.py in call(self, inputs)
#    1191
#    1192   def call(self, inputs):
# -> 1193     return core_ops.dense(
#    1194         inputs,
#    1195         self.kernel,
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\keras\layers\ops\core.py in dense(inputs, kernel, bias, activation, dtype)
#      62
#      63   if bias is not None:
# ---> 64     outputs = nn_ops.bias_add(outputs, bias)
#      65
#      66   if activation is not None:
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\ops\nn_ops.py in bias_add(value, bias, data_format, name)
#    3363         return math_ops.add(value, bias, name=name)
#    3364     else:
# -> 3365       return gen_nn_ops.bias_add(
#    3366           value, bias, data_format=data_format, name=name)
#    3367
#
# ~\.conda\envs\grad\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in bias_add(value, bias, data_format, name)
#     674   if tld.is_eager:
#     675     try:
# --> 676       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     677         _ctx._context_handle, tld.device_name, "BiasAdd", name,
#     678         tld.op_callbacks, value, bias, "data_format", data_format)
#
# KeyboardInterrupt:

# %%
# env = gym_tetris.make('TetrisA-v0')
# env = JoypadSpace(env, MOVEMENT)
# state, reward, done, info = env.step(env.action_space.sample())

# %%
### info
